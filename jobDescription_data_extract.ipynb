# %%
# avoids scroll-in-the-scroll in the entire Notebook
from IPython.display import Javascript
def resize_colab_cell():
    display(Javascript('google.colab.output.setIframeHeight(0, true, {maxHeight: 5000})'))
get_ipython().events.register('pre_run_cell', resize_colab_cell)

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 11.0 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("jacob-hugging-face/job-descriptions")
print(dataset)
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['company_name', 'job_description', 'position_title', 'description_length', 'model_response'],
#         num_rows: 853
#     })
# })

# %%
# considering 15 jobs to extract datas from
jobs = 15

for i in range(jobs):
    print("\n\nCOMPANY NAME: ", dataset["train"][i]["company_name"])
    # print("\nPOSITION TITLE: ", dataset["train"][i]["position_title"])
    # print("\nJOB DESCRIPTION: ", dataset["train"][i]["job_description"])
    print("\nMODEL RESPONSE", dataset["train"][i]["model_response"])
    print()
# Out:
# COMPANY NAME:  Google
#
# MODEL RESPONSE  {
#   "Core Responsibilities": "Responsible for expanding Google Workspace product adoption across an assigned territory. Build relationships with customers to understand needs and provide Google Workspace solutions. Partner with account teams to construct solutions and grow business for Google Workspace.",
#   "Required Skills": "Bachelor's degree or equivalent experience. Experience managing enterprise SaaS accounts and sales cycles.",
#   "Educational Requirements": "Bachelor's degree or equivalent experience.",
#   "Experience Level": "Experience managing enterprise SaaS accounts and sales cycles.",
#   "Preferred Qualifications": "Experience building strategic partnerships with enterprise customers. Ability to work through a reseller ecosystem. Excellent communication and strategic thinking skills.",
#   "Compensation and Benefits": "N/A"
# }
#
#
#
# COMPANY NAME:  Apple
#
# MODEL RESPONSE  {
# ...

# %%
company = []
position = []
skills = []
education = []

# storing essential datas (skills and education) acc. to company and position
for i in range(jobs):
    company.append(dataset["train"][i]["company_name"])
    position.append(dataset["train"][i]["position_title"])
    model_response = eval(dataset["train"][i]["model_response"])
    skills.append(model_response["Required Skills"]) if "Required Skills" in model_response else skills.append("N/A")
    education.append(model_response["Educational Requirements"]) if "Educational Requirements" in model_response else education.append("N/A")

# printing
for i in range(jobs): print(f"{company[i]} ({position[i]}): \nRequired Skills: {skills[i]} \nEducational Requirements: {education[i]}\n")
# Out:
# Google (Sales Specialist):
# Required Skills: Bachelor's degree or equivalent experience. Experience managing enterprise SaaS accounts and sales cycles.
# Educational Requirements: Bachelor's degree or equivalent experience.
#
# Apple (Apple Solutions Consultant):
# Required Skills: a passion to help people understand how apple products can enrich their livesexcellent communication skills allowing you to be as comfortable in front of a small group as you are speaking with individuals years preferred working in a dynamic sales andor results driven environment as well as proven success developing customer loyaltyability to encourage a partner team and grow apple business
# Educational Requirements: N/A
#
# Netflix (Licensing Coordinator - Consumer Products):
# ...
